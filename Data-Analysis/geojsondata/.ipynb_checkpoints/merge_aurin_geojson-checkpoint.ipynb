# %%
import json
import csv
from collections import defaultdict
import numpy as np
import pandas as pd
import couchdb

# %%
# Dict to store all data. sa4 as key.
data_dict = defaultdict(dict)

# %%
# data_dict

# %% [markdown]
# #### Get Tweet Counts and Sentiment scores for each SA4 (Must be Tunneled into Couchdb instance)

# %%
user = 'admin'
password = 'password'
COUCH_ADDRESS = 'localhost'

# Connect to Couch DB Server
# server = couchdb.Server("http://{}:{}@{}:5984/".format(user, password, COUCH_ADDRESS))
server = couchdb.Server("http://{}:{}@{}:15984/".format(user, password, COUCH_ADDRESS))
db = server['tweets']

# %%
tweet_counts = {}
sent_sum = {}
# Store Tweet Counts
for code in db.view('Results/TweetCount', group='true'):
    tweet_counts[code.key] = code.value

# Store Sentiment Scores
for code in db.view('Results/SentimentSum', group='true'):
    sent_sum[code.key] = code.value

# %%
for key in tweet_counts.keys():
    count = tweet_counts[key]
    sent = sent_sum[key]
    score = sent/count
    
    # store in data dict
    data_dict[key]['sentiment_score'] = score
    data_dict[key]['tweet_counts'] = count
    data_dict[key]['sent_sum'] = sent

# %% [markdown]
# #### Process data from Aurin & SA4 Geojson

# %%
# Import sa4 geojson file and aurin data files
sa4_geo_file = json.load(open('SA4_geojson.json'))
sa4_centroids = json.load(open('sa4_geojson_centroid.json'))


# crime data needs lga_sa4 conversion
crime_data = json.load(open('crimedata.json'))
income_data = json.load(open('equivalisedincomedata.json'))
family_data = json.load(open('familycommunitydata.json'))
unemployment_data = json.load(open('SA4_unemployment.json'))
population_data = json.load(open('populationdata.json'))
industry_data = json.load(open('industry.json'))

lga_sa4 = open('lga_sa4.csv', 'r')

# %%
# Process sa4 lga conversion
lga_sa4_dict = defaultdict(list)
for line in lga_sa4:
    line = line.strip('\n')
    (lga, sa4) = line.split(",")
    lga_sa4_dict[lga] = sa4
    
# Create DF for data analysis

# %%
def process_aurin(data_set, features):
    for feature in features:
        for item in data_set['features']:
            if item['properties']['sa4_code_2016'] in data_dict.keys():
                data_dict[item['properties']['sa4_code_2016']][feature] = item['properties'][feature]

# %%
def add_to_dict(key, d, val):
    if key in d:
        d[key] = d[key] + val
    else:
        d[key] = val

# %%
# Process crime sa4_lga conversion
# Add sa4 to each LGA in crime_data
for item in crime_data['features']:
    if item['properties']['lga_code'] in lga_sa4_dict.keys():
        
        a = item['properties']['total_division_a_offences']
        b = item['properties']['total_division_b_offences']
        c = item['properties']['total_division_c_offences']
        d = item['properties']['total_division_d_offences']
        e = item['properties']['total_division_e_offences']
        f = item['properties']['total_division_f_offences']
        sum_crimes = a+b+c+d+e+f
        
        item['properties']['sa4_code_2016'] = lga_sa4_dict[item['properties']['lga_code']]
        item['properties']['sum_crimes'] = sum_crimes

# %%
# Process income and family features
income_features = ['equivalised_total_household_income_census_median_weekly']
family_features = ['rent_mortgage_payments_census_average_monthly_household_payment']
crime_features = ['total_division_a_offences', 'total_division_b_offences', 'total_division_c_offences', 
                  'total_division_d_offences', 'total_division_e_offences', 'total_division_f_offences', 
                  'sum_crimes']

process_aurin(income_data, income_features)
process_aurin(family_data, family_features)
process_aurin(crime_data, crime_features)

# %%
# Process for Unemployment job search weeks data
for item in unemployment_data['features']:
    if str(item['properties']['sa4_code']) in data_dict.keys():
        data_dict[str(item['properties']['sa4_code'])]['unemployed_rate'] = item['properties']['unemployed_tot_000']
        data_dict[str(item['properties']['sa4_code'])]['avg_duration_job_search_wks'] = item['properties']['avg_duration_job_search_wks']

# %%
# Add population data
for item in population_data['features']:
    if item['properties']['sa4_code16'] in data_dict.keys():
        data_dict[item['properties']['sa4_code16']]['persons_total'] = item['properties']['persons_total']

# %%
# Put centroid in
for item in sa4_centroids['features']:
    if item['properties']['SA4_CODE16'] in data_dict.keys():
        data_dict[item['properties']['SA4_CODE16']]['centroid'] = item['geometry']['coordinates']

# %%
for item in industry_data['features']:
    if item['properties']['sa4_code_2016'] in data_dict.keys():
        data_dict[item['properties']['sa4_code_2016']]['num_recreation_busi'] = item['properties']['number_businesses_industry_30_june_arts_recreation_services_num']
        data_dict[item['properties']['sa4_code_2016']]['num_scientific_busi'] = item['properties']['nmbr_bsnsss_indstry_30_jne_prfssnl_scntfc_tchncl_srvcs_nm']
        data_dict[item['properties']['sa4_code_2016']]['num_mining_busi'] = item['properties']['number_of_businesses_by_industry_as_at_30_june_mining_num']
        data_dict[item['properties']['sa4_code_2016']]['num_finance_busi'] = item['properties']['nmbr_bsnsss_indstry_30_jne_fnncl_insrnce_srvcs_nm']
        data_dict[item['properties']['sa4_code_2016']]['num_agri_busi'] = item['properties']['nmbr_bsnsss_indstry_30_jne_agrcltre_frstry_fshng_nm']

# %% [markdown]
# ### Analysis of tweet data

# %%
# sentiment score vs household income
sent_scores = []
income = []
mortgage = []
unemployment = []
duration_jobsearch = []
num_recreation_busi = []
num_scientific_busi = []
num_mining_busi = []
num_finance_busi = []
num_agri_busi = []

for item in data_dict:
    try:
        sent_scores.append(data_dict[item]['sentiment_score'])
        income.append(data_dict[item]['equivalised_total_household_income_census_median_weekly']) 
        mortgage.append(data_dict[item]['rent_mortgage_payments_census_average_monthly_household_payment'])
        unemployment.append(data_dict[item]['unemployed_rate'])
        duration_jobsearch.append(data_dict[item]['avg_duration_job_search_wks'])
    except:
        print(item)
# Out:
# 801

# %%
data_dict
# Out:
# defaultdict(dict,
#             {'101': {'sentiment_score': 0.2846828662370934,
#               'tweet_counts': 38643,
#               'sent_sum': 11001,
#               'equivalised_total_household_income_census_median_weekly': 795,
#               'rent_mortgage_payments_census_average_monthly_household_payment': 1805,
#               'unemployed_rate': 5.76200061,
#               'avg_duration_job_search_wks': 21.29717775,
#               'persons_total': 225666,
#               'centroid': [149.24, -35.56],
#               'num_recreation_busi': 264,
#               'num_scientific_busi': 1795,
#               'num_mining_busi': 59,
#               'num_finance_busi': 1048,
#               'num_agri_busi': 5059},
#              '102': {'sentiment_score': 0.008370183196462414,
#               'tweet_counts': 18996,
#               'sent_sum': 159,
#               'equivalised_total_household_income_census_median_weekly': 774,
#               'rent_mortgage_payments_census_average_monthly_household_payment': 1890,
#               'unemployed_rate': 9.20597806,
#               'avg_duration_job_search_wks': 13.63987744,
#               'persons_total': 339236,
#               'centroid': [151.29, -33.31],
#               'num_recreation_busi': 410,
#               'num_scientific_busi': 2985,
#               'num_mining_busi': 52,
#               'num_finance_busi': 1916,
#               'num_agri_busi': 512},
#              '103': {'sentiment_score': 0.36140350877192984,
#               'tweet_counts': 855,
#               'sent_sum': 309,
#               'equivalised_total_household_income_census_median_weekly': 742,
#               'rent_mortgage_payments_census_average_monthly_household_payment': 1625,
#               'unemployed_rate': 5.62297262,
#               'avg_duration_job_search_wks': 28.56614978,
#               'persons_total': 211224,
#               'centroid': [148.36, -33.22],
#               'num_recreation_busi': 192,
#               'num_scientific_busi': 1282,
#               'num_mining_busi': 109,
#               'num_finance_busi': 1006,
#               'num_agri_busi': 6709},
#              '104': {'sentiment_score': 0.24645892351274787,
#               'tweet_counts': 353,
#               'sent_sum': 87,
#               'equivalised_total_household_income_census_median_weekly': 648,
#               'rent_mortgage_payments_census_average_monthly_household_payment': 1568,
#               'unemployed_rate': 2.2809204,
#               'avg_duration_job_search_wks': 138.1122137,
#               'persons_total': 140070,
#               'centroid': [152.77, -29.82],
#               'num_recreation_busi': 150,
#               'num_scientific_busi': 920,
#               'num_mining_busi': 33,
#               'num_finance_busi': 749,
#               'num_agri_busi': 1881},
#              '106': {'sentiment_score': 0.8275862068965517,
#               'tweet_counts': 812,
#               'sent_sum': 672,
#               'equivalised_total_household_income_census_median_weekly': 786,
#               'rent_mortgage_payments_census_average_monthly_household_payment': 1801,
#               'unemployed_rate': 7.07587226,
#               'avg_duration_job_search_wks': 25.03552685,
#               'persons_total': 272452,
#               'centroid': [150.98, -32.35],
#               'num_recreation_busi': 250,
#               'num_scientific_busi': 1707,
#               'num_mining_busi': 85,
#               'num_finance_busi': 2248,
#               'num_agri_busi': 2914},
#              '107': {'sentiment_score': 0.5268772098040391,
#               'tweet_counts': 16687,
#               'sent_sum': 8792,
#               'equivalised_total_household_income_census_median_weekly': 811,
#               'rent_mortgage_payments_census_average_monthly_household_payment': 2019,
#               'unemployed_rate': 9.99014274,
#               'avg_duration_job_search_wks': 40.64288005,
#               'persons_total': 306591,
#               'centroid': [150.77, -34.43],
#               'num_recreation_busi': 309,
#               'num_scientific_busi': 2425,
#               'num_mining_busi': 37,
#               'num_finance_busi': 1530,
#               'num_agri_busi': 328},
#              '108': {'sentiment_score': 0.47575531518090264,
#               'tweet_counts': 5362,
#               'sent_sum': 2551,
#               'equivalised_total_household_income_census_median_weekly': 615,
#               'rent_mortgage_payments_census_average_monthly_household_payment': 1556,
#               'unemployed_rate': 11.81105483,
#               'avg_duration_job_search_wks': 48.75290733,
#               'persons_total': 218256,
#               'centroid': [152.34, -31.56],
#               'num_recreation_busi': 182,
#               'num_scientific_busi': 1255,
#               'num_mining_busi': 38,
#               'num_finance_busi': 1037,
#               'num_agri_busi': 3056},
#              '110': {'sentiment_score': 0.6646294881588999,
#               'tweet_counts': 1309,
#               'sent_sum': 870,
#               'equivalised_total_household_income_census_median_weekly': 710,
#               'rent_mortgage_payments_census_average_monthly_household_payment': 1498,
#               'unemployed_rate': 5.65170182,
#               'avg_duration_job_search_wks': 95.45232328,
#               'persons_total': 186181,
#               'centroid': [150.7, -30.06],
#               'num_recreation_busi': 157,
#               'num_scientific_busi': 1080,
#               'num_mining_busi': 51,
#               'num_finance_busi': 1019,
#               'num_agri_busi': 7860},
#              '111': {'sentiment_score': 0.5774343603417739,
#               'tweet_counts': 51379,
#               'sent_sum': 29668,
#               'equivalised_total_household_income_census_median_weekly': 829,
#               'rent_mortgage_payments_census_average_monthly_household_payment': 1878,
#               'unemployed_rate': 14.84434741,
#               'avg_duration_job_search_wks': 19.072142,
#               'persons_total': 372264,
#               'centroid': [151.57, -32.99],
#               'num_recreation_busi': 428,
#               'num_scientific_busi': 3567,
#               'num_mining_busi': 70,
#               'num_finance_busi': 2909,
#               'num_agri_busi': 310},
#              '112': {'sentiment_score': 0.9062082777036048,
#               'tweet_counts': 2996,
#               'sent_sum': 2715,
#               'equivalised_total_household_income_census_median_weekly': 686,
#               'rent_mortgage_payments_census_average_monthly_household_payment': 1716,
#               'unemployed_rate': 6.97952289,
#               'avg_duration_job_search_wks': 81.57501489,
#               'persons_total': 248488,
#               'centroid': [153.06, -28.74],
#               'num_recreation_busi': 381,
#               'num_scientific_busi': 2437,
#               'num_mining_busi': 45,
#               'num_finance_busi': 1429,
#               'num_agri_busi': 3711},
#              '113': {'sentiment_score': 0.6043478260869565,
#               'tweet_counts': 460,
#               'sent_sum': 278,
#               'equivalised_total_household_income_census_median_weekly': 776,
#               'rent_mortgage_payments_census_average_monthly_household_payment': 1511,
#               'unemployed_rate': 5.88110378,
#               'avg_duration_job_search_wks': 81.55310155,
#               'persons_total': 160049,
#               'centroid': [146.77, -34.62],
#               'num_recreation_busi': 100,
#               'num_scientific_busi': 797,
#               'num_mining_busi': 20,
#               'num_finance_busi': 1209,
#               'num_agri_busi': 5286},
#              '114': {'sentiment_score': 0.6914512922465209,
#               'tweet_counts': 2515,
#               'sent_sum': 1739,
#               'equivalised_total_household_income_census_median_weekly': 698,
#               'rent_mortgage_payments_census_average_monthly_household_payment': 1757,
#               'unemployed_rate': 2.85099504,
#               'avg_duration_job_search_wks': 6.083616189,
#               'persons_total': 152510,
#               'centroid': [150.37, -34.87],
#               'num_recreation_busi': 188,
#               'num_scientific_busi': 1463,
#               'num_mining_busi': 18,
#               'num_finance_busi': 924,
#               'num_agri_busi': 1025},
#              '115': {'sentiment_score': 0.3584905660377358,
#               'tweet_counts': 159,
#               'sent_sum': 57,
#               'equivalised_total_household_income_census_median_weekly': 1182,
#               'rent_mortgage_payments_census_average_monthly_household_payment': 2596,
#               'unemployed_rate': 6.76042518,
#               'avg_duration_job_search_wks': 12.38739883,
#               'persons_total': 240876,
#               'centroid': [150.83, -33.37],
#               'num_recreation_busi': 343,
#               'num_scientific_busi': 4744,
#               'num_mining_busi': 28,
#               'num_finance_busi': 3286,
#               'num_agri_busi': 751},
#              '116': {'sentiment_score': 0.7109144542772862,
#               'tweet_counts': 678,
#               'sent_sum': 482,
#               'equivalised_total_household_income_census_median_weekly': 895,
#               'rent_mortgage_payments_census_average_monthly_household_payment': 2203,
#               'unemployed_rate': 14.3306232,
#               'avg_duration_job_search_wks': 18.03434379,
#               'persons_total': 360060,
#               'centroid': [150.86, -33.74],
#               'num_recreation_busi': 211,
#               'num_scientific_busi': 2578,
#               'num_mining_busi': 10,
#               'num_finance_busi': 1325,
#               'num_agri_busi': 150},
#              '117': {'sentiment_score': 0.3358879492600423,
#               'tweet_counts': 3784,
#               'sent_sum': 1271,
#               'equivalised_total_household_income_census_median_weekly': 1266,
#               'rent_mortgage_payments_census_average_monthly_household_payment': 2614,
#               'unemployed_rate': 17.96015339,
#               'avg_duration_job_search_wks': 4.432223117,
#               'persons_total': 348695,
#               'centroid': [151.19, -33.92],
#               'num_recreation_busi': 1474,
#               'num_scientific_busi': 17831,
#               'num_mining_busi': 379,
#               'num_finance_busi': 13743,
#               'num_agri_busi': 476},
#              '118': {'sentiment_score': 0.14231499051233396,
#               'tweet_counts': 1054,
#               'sent_sum': 150,
#               'equivalised_total_household_income_census_median_weekly': 1410,
#               'rent_mortgage_payments_census_average_monthly_household_payment': 2950,
#               'unemployed_rate': 12.38259285,
#               'avg_duration_job_search_wks': 8.247501766,
#               'persons_total': 289483,
#               'centroid': [151.25, -33.92],
#               'num_recreation_busi': 892,
#               'num_scientific_busi': 6753,
#               'num_mining_busi': 27,
#               'num_finance_busi': 3982,
#               'num_agri_busi': 268},
#              '119': {'sentiment_score': 0.36589861751152075,
#               'tweet_counts': 1085,
#               'sent_sum': 397,
#               'equivalised_total_household_income_census_median_weekly': 799,
#               'rent_mortgage_payments_census_average_monthly_household_payment': 2263,
#               'unemployed_rate': 27.12842495,
#               'avg_duration_job_search_wks': 30.81064226,
#               'persons_total': 610511,
#               'centroid': [151.06, -33.94],
#               'num_recreation_busi': 524,
#               'num_scientific_busi': 5978,
#               'num_mining_busi': 31,
#               'num_finance_busi': 3482,
#               'num_agri_busi': 176},
#              '120': {'sentiment_score': 0.603875968992248,
#               'tweet_counts': 1290,
#               'sent_sum': 779,
#               'equivalised_total_household_income_census_median_weekly': 1179,
#               'rent_mortgage_payments_census_average_monthly_household_payment': 2666,
#               'unemployed_rate': 14.70834147,
#               'avg_duration_job_search_wks': 16.5081699,
#               'persons_total': 313927,
#               'centroid': [151.12, -33.87],
#               'num_recreation_busi': 626,
#               'num_scientific_busi': 6053,
#               'num_mining_busi': 19,
#               'num_finance_busi': 3158,
#               'num_agri_busi': 181},
#              '121': {'sentiment_score': 1.4864864864864864,
#               'tweet_counts': 1739,
#               'sent_sum': 2585,
#               'equivalised_total_household_income_census_median_weekly': 1475,
#               'rent_mortgage_payments_census_average_monthly_household_payment': 2823,
#               'unemployed_rate': 8.07504961,
#               'avg_duration_job_search_wks': 12.87935395,
#               'persons_total': 431008,
#               'centroid': [151.16, -33.69],
#               'num_recreation_busi': 873,
#               'num_scientific_busi': 13992,
#               'num_mining_busi': 109,
#               'num_finance_busi': 9615,
#               'num_agri_busi': 625},
#              '122': {'sentiment_score': 0.2975609756097561,
#               'tweet_counts': 205,
#               'sent_sum': 61,
#               'equivalised_total_household_income_census_median_weekly': 1266,
#               'rent_mortgage_payments_census_average_monthly_household_payment': 2870,
#               'unemployed_rate': 7.08317923,
#               'avg_duration_job_search_wks': 14.37321455,
#               'persons_total': 268666,
#               'centroid': [151.25, -33.69],
#               'num_recreation_busi': 586,
#               'num_scientific_busi': 6787,
#               'num_mining_busi': 21,
#               'num_finance_busi': 3775,
#               'num_agri_busi': 273},
#              '123': {'sentiment_score': 0.4241741741741742,
#               'tweet_counts': 1332,
#               'sent_sum': 565,
#               'equivalised_total_household_income_census_median_weekly': 901,
#               'rent_mortgage_payments_census_average_monthly_household_payment': 2092,
#               'unemployed_rate': 12.01282399,
#               'avg_duration_job_search_wks': 20.22476159,
#               'persons_total': 275946,
#               'centroid': [150.68, -34.12],
#               'num_recreation_busi': 256,
#               'num_scientific_busi': 1840,
#               'num_mining_busi': 24,
#               'num_finance_busi': 1172,
#               'num_agri_busi': 403},
#              '124': {'sentiment_score': 0.3034722222222222,
#               'tweet_counts': 1440,
#               'sent_sum': 437,
#               'equivalised_total_household_income_census_median_weekly': 925,
#               'rent_mortgage_payments_census_average_monthly_household_payment': 2029,
#               'unemployed_rate': 7.57876917,
#               'avg_duration_job_search_wks': 26.73319488,
#               'persons_total': 319008,
#               'centroid': [150.38, -33.87],
#               'num_recreation_busi': 381,
#               'num_scientific_busi': 2423,
#               'num_mining_busi': 15,
#               'num_finance_busi': 1425,
#               'num_agri_busi': 420},
#              '125': {'sentiment_score': 0.5395095367847411,
#               'tweet_counts': 1101,
#               'sent_sum': 594,
#               'equivalised_total_household_income_census_median_weekly': 844,
#               'rent_mortgage_payments_census_average_monthly_household_payment': 2190,
#               'unemployed_rate': 13.64156119,
#               'avg_duration_job_search_wks': 9.8892494,
#               'persons_total': 480925,
#               'centroid': [151.01, -33.83],
#               'num_recreation_busi': 335,
#               'num_scientific_busi': 5424,
#               'num_mining_busi': 24,
#               'num_finance_busi': 2788,
#               'num_agri_busi': 156},
#              '126': {'sentiment_score': 0.3333333333333333,
#               'tweet_counts': 54,
#               'sent_sum': 18,
#               'equivalised_total_household_income_census_median_weekly': 1126,
#               'rent_mortgage_payments_census_average_monthly_household_payment': 2567,
#               'unemployed_rate': 10.42517949,
#               'avg_duration_job_search_wks': 25.40424934,
#               'persons_total': 194360,
#               'centroid': [151.1, -33.79],
#               'num_recreation_busi': 203,
#               'num_scientific_busi': 3747,
#               'num_mining_busi': 14,
#               'num_finance_busi': 2099,
#               'num_agri_busi': 123},
#              '127': {'sentiment_score': 0.6080598733448475,
#               'tweet_counts': 8685,
#               'sent_sum': 5281,
#               'equivalised_total_household_income_census_median_weekly': 738,
#               'rent_mortgage_payments_census_average_monthly_household_payment': 2127,
#               'unemployed_rate': 16.61935069,
#               'avg_duration_job_search_wks': 23.16766579,
#               'persons_total': 432659,
#               'centroid': [150.82, -33.93],
#               'num_recreation_busi': 268,
#               'num_scientific_busi': 2547,
#               'num_mining_busi': 20,
#               'num_finance_busi': 1787,
#               'num_agri_busi': 575},
#              '128': {'sentiment_score': 0.39078498293515357,
#               'tweet_counts': 586,
#               'sent_sum': 229,
#               'equivalised_total_household_income_census_median_weekly': 1135,
#               'rent_mortgage_payments_census_average_monthly_household_payment': 2559,
#               'unemployed_rate': 2.721795,
#               'avg_duration_job_search_wks': 7.215555499,
#               'persons_total': 226995,
#               'centroid': [151.06, -34.08],
#               'num_recreation_busi': 329,
#               'num_scientific_busi': 3363,
#               'num_mining_busi': 9,
#               'num_finance_busi': 2327,
#               'num_agri_busi': 129},
#              '201': {'sentiment_score': 0.5795361527967258,
#               'tweet_counts': 7330,
#               'sent_sum': 4248,
#               'equivalised_total_household_income_census_median_weekly': 707,
#               'rent_mortgage_payments_census_average_monthly_household_payment': 1457,
#               'total_division_a_offences': 179,
#               'total_division_b_offences': 532,
#               'total_division_c_offences': 15,
#               'total_division_d_offences': 19,
#               'total_division_e_offences': 117,
#               'total_division_f_offences': 3,
#               'sum_crimes': 865,
#               'unemployed_rate': 3.05898974,
#               'avg_duration_job_search_wks': 89.66276354,
#               'persons_total': 162362,
#               'centroid': [143.73, -37.38],
#               'num_recreation_busi': 214,
#               'num_scientific_busi': 1281,
#               'num_mining_busi': 47,
#               'num_finance_busi': 1353,
#               'num_agri_busi': 1936},
#              '202': {'sentiment_score': 0.22388859132297803,
#               'tweet_counts': 5601,
#               'sent_sum': 1254,
#               'equivalised_total_household_income_census_median_weekly': 741,
#               'rent_mortgage_payments_census_average_monthly_household_payment': 1491,
#               'total_division_a_offences': 1627,
#               'total_division_b_offences': 5234,
#               'total_division_c_offences': 460,
#               'total_division_d_offences': 760,
#               'total_division_e_offences': 2170,
#               'total_division_f_offences': 16,
#               'sum_crimes': 10267,
#               'unemployed_rate': 2.35266111,
#               'avg_duration_job_search_wks': 19.51505307,
#               'persons_total': 157827,
#               'centroid': [144.09, -36.6],
#               'num_recreation_busi': 211,
#               'num_scientific_busi': 1274,
#               'num_mining_busi': 42,
#               'num_finance_busi': 908,
#               'num_agri_busi': 1782},
#              '203': {'sentiment_score': 0.5885714285714285,
#               'tweet_counts': 3150,
#               'sent_sum': 1854,
#               'equivalised_total_household_income_census_median_weekly': 804,
#               'rent_mortgage_payments_census_average_monthly_household_payment': 1692,
#               'total_division_a_offences': 3119,
#               'total_division_b_offences': 13995,
#               'total_division_c_offences': 1079,
#               'total_division_d_offences': 1287,
#               'total_division_e_offences': 2809,
#               'total_division_f_offences': 47,
#               'sum_crimes': 22336,
#               'unemployed_rate': 3.17913091,
#               'avg_duration_job_search_wks': 7.41924635,
#               'persons_total': 294004,
#               'centroid': [144.13, -38.11],
#               'num_recreation_busi': 357,
#               'num_scientific_busi': 2738,
#               'num_mining_busi': 28,
#               'num_finance_busi': 2019,
#               'num_agri_busi': 1353},
#              '204': {'sentiment_score': -0.14501160092807425,
#               'tweet_counts': 862,
#               'sent_sum': -125,
#               'equivalised_total_household_income_census_median_weekly': 730,
#               'rent_mortgage_payments_census_average_monthly_household_payment': 1471,
#               'total_division_a_offences': 640,
#               'total_division_b_offences': 1587,
#               'total_division_c_offences': 180,
#               'total_division_d_offences': 234,
#               'total_division_e_offences': 504,
#               'total_division_f_offences': 8,
#               'sum_crimes': 3153,
#               'unemployed_rate': 2.5073013,
#               'avg_duration_job_search_wks': 28.48161307,
#               'persons_total': 174602,
#               'centroid': [146.41, -36.78],
#               'num_recreation_busi': 206,
#               'num_scientific_busi': 1260,
#               'num_mining_busi': 44,
#               'num_finance_busi': 953,
#               'num_agri_busi': 4810},
#              '205': {'sentiment_score': 0.2561863173216885,
#               'tweet_counts': 2061,
#               'sent_sum': 528,
#               'equivalised_total_household_income_census_median_weekly': 682,
#               'rent_mortgage_payments_census_average_monthly_household_payment': 1433,
#               'total_division_a_offences': 951,
#               'total_division_b_offences': 1744,
#               'total_division_c_offences': 196,
#               'total_division_d_offences': 388,
#               'total_division_e_offences': 831,
#               'total_division_f_offences': 6,
#               'sum_crimes': 4116,
#               'unemployed_rate': 5.71246809,
#               'avg_duration_job_search_wks': 29.02131218,
#               'persons_total': 279350,
#               'centroid': [147.43, -37.72],
#               'num_recreation_busi': 244,
#               'num_scientific_busi': 1647,
#               'num_mining_busi': 70,
#               'num_finance_busi': 1608,
#               'num_agri_busi': 6236},
#              '206': {'sentiment_score': 0.5151945557730666,
#               'tweet_counts': 323866,
#               'sent_sum': 166854,
#               'equivalised_total_household_income_census_median_weekly': 1190,
#               'rent_mortgage_payments_census_average_monthly_household_payment': 2335,
#               'total_division_a_offences': 1457,
#               'total_division_b_offences': 9022,
#               'total_division_c_offences': 785,
#               'total_division_d_offences': 912,
#               'total_division_e_offences': 984,
#               'total_division_f_offences': 19,
#               'sum_crimes': 13179,
#               'unemployed_rate': 29.87540254,
#               'avg_duration_job_search_wks': 13.8817047,
#               'persons_total': 658592,
#               'centroid': [144.96, -37.8],
#               'num_recreation_busi': 2274,
#               'num_scientific_busi': 22777,
#               'num_mining_busi': 268,
#               'num_finance_busi': 16328,
#               'num_agri_busi': 1053},
#              '207': {'sentiment_score': 0.8090507726269316,
#               'tweet_counts': 906,
#               'sent_sum': 733,
#               'equivalised_total_household_income_census_median_weekly': 1064,
#               'rent_mortgage_payments_census_average_monthly_household_payment': 2439,
#               'total_division_a_offences': 879,
#               'total_division_b_offences': 5669,
#               'total_division_c_offences': 315,
#               'total_division_d_offences': 357,
#               'total_division_e_offences': 621,
#               'total_division_f_offences': 22,
#               'sum_crimes': 7863,
#               'unemployed_rate': 15.94644102,
#               'avg_duration_job_search_wks': 22.85740945,
#               'persons_total': 385961,
#               'centroid': [145.1, -37.8],
#               'num_recreation_busi': 573,
#               'num_scientific_busi': 8251,
#               'num_mining_busi': 36,
#               'num_finance_busi': 6937,
#               'num_agri_busi': 470},
#              '208': {'sentiment_score': 0.6756893498608652,
#               'tweet_counts': 7906,
#               'sent_sum': 5342,
#               'equivalised_total_household_income_census_median_weekly': 1116,
#               'rent_mortgage_payments_census_average_monthly_household_payment': 2369,
#               'total_division_a_offences': 1000,
#               'total_division_b_offences': 4632,
#               'total_division_c_offences': 392,
#               'total_division_d_offences': 390,
#               'total_division_e_offences': 614,
#               'total_division_f_offences': 34,
#               'sum_crimes': 7062,
#               'unemployed_rate': 14.08333414,
#               'avg_duration_job_search_wks': 16.66238375,
#               'persons_total': 432905,
#               'centroid': [145.06, -37.95],
#               'num_recreation_busi': 793,
#               'num_scientific_busi': 9015,
#               'num_mining_busi': 20,
#               'num_finance_busi': 6043,
#               'num_agri_busi': 447},
#              '209': {'sentiment_score': 1.096026490066225,
#               'tweet_counts': 604,
#               'sent_sum': 662,
#               'equivalised_total_household_income_census_median_weekly': 888,
#               'rent_mortgage_payments_census_average_monthly_household_payment': 1959,
#               'total_division_a_offences': 2475,
#               'total_division_b_offences': 9787,
#               'total_division_c_offences': 795,
#               'total_division_d_offences': 550,
#               'total_division_e_offences': 2086,
#               'total_division_f_offences': 17,
#               'sum_crimes': 15710,
#               'unemployed_rate': 15.76510278,
#               'avg_duration_job_search_wks': 40.38407355,
#               'persons_total': 533213,
#               'centroid': [145.17, -37.52],
#               'num_recreation_busi': 532,
#               'num_scientific_busi': 4982,
#               'num_mining_busi': 27,
#               'num_finance_busi': 3138,
#               'num_agri_busi': 473},
#              '210': {'sentiment_score': 0.44601889338731443,
#               'tweet_counts': 1482,
#               'sent_sum': 661,
#               'equivalised_total_household_income_census_median_weekly': 808,
#               'rent_mortgage_payments_census_average_monthly_household_payment': 1849,
#               'total_division_a_offences': 1762,
#               'total_division_b_offences': 8907,
#               'total_division_c_offences': 580,
#               'total_division_d_offences': 599,
#               'total_division_e_offences': 1354,
#               'total_division_f_offences': 36,
#               'sum_crimes': 13238,
#               'unemployed_rate': 15.93719962,
#               'avg_duration_job_search_wks': 30.88239675,
#               'persons_total': 393361,
#               'centroid': [144.75, -37.48],
#               'num_recreation_busi': 334,
#               'num_scientific_busi': 2883,
#               'num_mining_busi': 16,
#               'num_finance_busi': 2162,
#               'num_agri_busi': 561},
#              '211': {'sentiment_score': 0.21952224052718286,
#               'tweet_counts': 2428,
#               'sent_sum': 533,
#               'equivalised_total_household_income_census_median_weekly': 915,
#               'rent_mortgage_payments_census_average_monthly_household_payment': 1889,
#               'total_division_a_offences': 1176,
#               'total_division_b_offences': 5663,
#               'total_division_c_offences': 377,
#               'total_division_d_offences': 363,
#               'total_division_e_offences': 717,
#               'total_division_f_offences': 42,
#               'sum_crimes': 8338,
#               'unemployed_rate': 14.92504248,
#               'avg_duration_job_search_wks': 57.95169807,
#               'persons_total': 525774,
#               'centroid': [145.51, -37.76],
#               'num_recreation_busi': 526,
#               'num_scientific_busi': 5997,
#               'num_mining_busi': 48,
#               'num_finance_busi': 3707,
#               'num_agri_busi': 988},
#              '212': {'sentiment_score': 0.6541725601131542,
#               'tweet_counts': 1414,
#               'sent_sum': 925,
#               'equivalised_total_household_income_census_median_weekly': 807,
#               'rent_mortgage_payments_census_average_monthly_household_payment': 1868,
#               'total_division_a_offences': 3249,
#               'total_division_b_offences': 10028,
#               'total_division_c_offences': 1445,
#               'total_division_d_offences': 1616,
#               'total_division_e_offences': 2673,
#               'total_division_f_offences': 48,
#               'sum_crimes': 19059,
#               'unemployed_rate': 38.05457417,
#               'avg_duration_job_search_wks': 24.03782388,
#               'persons_total': 818212,
#               'centroid': [145.47, -38.07],
#               'num_recreation_busi': 696,
#               'num_scientific_busi': 7298,
#               'num_mining_busi': 52,
#               'num_finance_busi': 4805,
#               'num_agri_busi': 1375},
#              '213': {'sentiment_score': 0.8181818181818182,
#               'tweet_counts': 2827,
#               'sent_sum': 2313,
#               'equivalised_total_household_income_census_median_weekly': 843,
#               'rent_mortgage_payments_census_average_monthly_household_payment': 1836,
#               'total_division_a_offences': 2248,
#               'total_division_b_offences': 8470,
#               'total_division_c_offences': 653,
#               'total_division_d_offences': 793,
#               'total_division_e_offences': 1816,
#               'total_division_f_offences': 41,
#               'sum_crimes': 14021,
#               'unemployed_rate': 35.94507126,
#               'avg_duration_job_search_wks': 36.36859346,
#               'persons_total': 791177,
#               'centroid': [144.62, -37.78],
#               'num_recreation_busi': 657,
#               'num_scientific_busi': 6008,
#               'num_mining_busi': 33,
#               'num_finance_busi': 3373,
#               'num_agri_busi': 571},
#              '214': {'sentiment_score': 0.3835021707670043,
#               'tweet_counts': 691,
#               'sent_sum': 265,
#               'equivalised_total_household_income_census_median_weekly': 821,
#               'rent_mortgage_payments_census_average_monthly_household_payment': 1797,
#               'total_division_a_offences': 1541,
#               'total_division_b_offences': 6258,
#               'total_division_c_offences': 653,
#               'total_division_d_offences': 1212,
#               'total_division_e_offences': 1770,
#               'total_division_f_offences': 32,
#               'sum_crimes': 11466,
#               'unemployed_rate': 10.02406647,
#               'avg_duration_job_search_wks': 27.00558709,
#               'persons_total': 304586,
#               'centroid': [145.06, -38.31],
#               'num_recreation_busi': 438,
#               'num_scientific_busi': 3025,
#               'num_mining_busi': 31,
#               'num_finance_busi': 2281,
#               'num_agri_busi': 657},
#              '215': {'sentiment_score': 0.24942263279445728,
#               'tweet_counts': 433,
#               'sent_sum': 108,
#               'equivalised_total_household_income_census_median_weekly': 664,
#               'rent_mortgage_payments_census_average_monthly_household_payment': 1227,
#               'total_division_a_offences': 166,
#               'total_division_b_offences': 183,
#               'total_division_c_offences': 8,
#               'total_division_d_offences': 18,
#               'total_division_e_offences': 67,
#               'total_division_f_offences': 4,
#               'sum_crimes': 446,
#               'unemployed_rate': 2.37130215,
#               'avg_duration_job_search_wks': 6.617086245,
#               'persons_total': 152094,
#               'centroid': [142.24, -35.87],
#               'num_recreation_busi': 114,
#               'num_scientific_busi': 704,
#               'num_mining_busi': 39,
#               'num_finance_busi': 920,
#               'num_agri_busi': 6771},
#              '216': {'sentiment_score': 0.777027027027027,
#               'tweet_counts': 296,
#               'sent_sum': 230,
#               'equivalised_total_household_income_census_median_weekly': 704,
#               'rent_mortgage_payments_census_average_monthly_household_payment': 1417,
#               'total_division_a_offences': 455,
#               'total_division_b_offences': 949,
#               'total_division_c_offences': 151,
#               'total_division_d_offences': 132,
#               'total_division_e_offences': 381,
#               'total_division_f_offences': 3,
#               'sum_crimes': 2071,
#               'unemployed_rate': 5.79374511,
#               'avg_duration_job_search_wks': 6.65109109,
#               'persons_total': 132910,
#               'centroid': [145.17, -36.25],
#               'num_recreation_busi': 118,
#               'num_scientific_busi': 813,
#               'num_mining_busi': 19,
#               'num_finance_busi': 831,
#               'num_agri_busi': 3922},
#              '217': {'sentiment_score': 0.5654952076677316,
#               'tweet_counts': 939,
#               'sent_sum': 531,
#               'equivalised_total_household_income_census_median_weekly': 716,
#               'rent_mortgage_payments_census_average_monthly_household_payment': 1393,
#               'total_division_a_offences': 317,
#               'total_division_b_offences': 820,
#               'total_division_c_offences': 92,
#               'total_division_d_offences': 114,
#               'total_division_e_offences': 320,
#               'total_division_f_offences': 4,
#               'sum_crimes': 1667,
#               'unemployed_rate': 0.97750665,
#               'avg_duration_job_search_wks': 15.33100745,
#               'persons_total': 124718,
#               'centroid': [142.38, -37.97],
#               'num_recreation_busi': 124,
#               'num_scientific_busi': 580,
#               'num_mining_busi': 26,
#               'num_finance_busi': 702,
#               'num_agri_busi': 5396},
#              '301': {'sentiment_score': 0.2017167381974249,
#               'tweet_counts': 466,
#               'sent_sum': 94,
#               'equivalised_total_household_income_census_median_weekly': 938,
#               'rent_mortgage_payments_census_average_monthly_household_payment': 2052,
#               'unemployed_rate': 12.24969763,
#               'avg_duration_job_search_wks': 48.40467739,
#               'persons_total': 234632,
#               'centroid': [153.22, -27.54],
#               'num_recreation_busi': 223,
#               'num_scientific_busi': 2708,
#               'num_mining_busi': 45,
#               'num_finance_busi': 1676,
#               'num_agri_busi': 290},
#              '302': {'sentiment_score': 0.603042876901798,
#               'tweet_counts': 723,
#               'sent_sum': 436,
#               'equivalised_total_household_income_census_median_weekly': 1003,
#               'rent_mortgage_payments_census_average_monthly_household_payment': 2024,
#               'unemployed_rate': 7.67977713,
#               'avg_duration_job_search_wks': 16.31565956,
#               'persons_total': 218521,
#               'centroid': [153.06, -27.37],
#               'num_recreation_busi': 251,
#               'num_scientific_busi': 2469,
#               'num_mining_busi': 40,
#               'num_finance_busi': 1306,
#               'num_agri_busi': 119},
#              '303': {'sentiment_score': 0.20458196773986248,
#               'tweet_counts': 31122,
#               'sent_sum': 6367,
#               'equivalised_total_household_income_census_median_weekly': 980,
#               'rent_mortgage_payments_census_average_monthly_household_payment': 2087,
#               'unemployed_rate': 8.21811277,
#               'avg_duration_job_search_wks': 27.57065242,
#               'persons_total': 363988,
#               'centroid': [153.07, -27.57],
#               'num_recreation_busi': 393,
#               'num_scientific_busi': 4669,
#               'num_mining_busi': 54,
#               'num_finance_busi': 3067,
#               'num_agri_busi': 311},
#              '304': {'sentiment_score': 0.5778546712802768,
#               'tweet_counts': 289,
#               'sent_sum': 167,
#               'equivalised_total_household_income_census_median_weekly': 1149,
#               'rent_mortgage_payments_census_average_monthly_household_payment': 2236,
#               'unemployed_rate': 4.85540891,
#               'avg_duration_job_search_wks': 21.09563961,
#               'persons_total': 189504,
#               'centroid': [152.9, -27.48],
#               'num_recreation_busi': 215,
#               'num_scientific_busi': 3379,
#               'num_mining_busi': 63,
#               'num_finance_busi': 1667,
#               'num_agri_busi': 224},
#              '305': {'sentiment_score': 0.5331226768758108,
#               'tweet_counts': 125639,
#               'sent_sum': 66981,
#               'equivalised_total_household_income_census_median_weekly': 1284,
#               'rent_mortgage_payments_census_average_monthly_household_payment': 2479,
#               'unemployed_rate': 15.82941563,
#               'avg_duration_job_search_wks': 17.03952272,
#               'persons_total': 273860,
#               'centroid': [153.02, -27.45],
#               'num_recreation_busi': 703,
#               'num_scientific_busi': 9902,
#               'num_mining_busi': 426,
#               'num_finance_busi': 8292,
#               'num_agri_busi': 517},
#              '306': {'sentiment_score': 0.7452830188679245,
#               'tweet_counts': 212,
#               'sent_sum': 158,
#               'equivalised_total_household_income_census_median_weekly': 780,
#               'rent_mortgage_payments_census_average_monthly_household_payment': 1694,
#               'unemployed_rate': 8.44574154,
#               'avg_duration_job_search_wks': 71.02177777,
#               'persons_total': 249745,
#               'centroid': [145.49, -17.61],
#               'num_recreation_busi': 261,
#               'num_scientific_busi': 1939,
#               'num_mining_busi': 109,
#               'num_finance_busi': 1458,
#               'num_agri_busi': 3150},
#              '307': {'sentiment_score': 1.4,
#               'tweet_counts': 5,
#               'sent_sum': 7,
#               'equivalised_total_household_income_census_median_weekly': 710,
#               'rent_mortgage_payments_census_average_monthly_household_payment': 1472,
#               'unemployed_rate': 3.92701574,
#               'avg_duration_job_search_wks': 37.54333506,
#               'persons_total': 128798,
#               'centroid': [149.36, -27.32],
#               'num_recreation_busi': 119,
#               'num_scientific_busi': 650,
#               'num_mining_busi': 81,
#               'num_finance_busi': 748,
#               'num_agri_busi': 9002},
#              '309': {'sentiment_score': 0.5779868768796136,
#               'tweet_counts': 43892,
#               'sent_sum': 25369,
#               'equivalised_total_household_income_census_median_weekly': 858,
#               'rent_mortgage_payments_census_average_monthly_household_payment': 2007,
#               'unemployed_rate': 22.7433752,
#               'avg_duration_job_search_wks': 16.13783282,
#               'persons_total': 606291,
#               'centroid': [153.27, -28.02],
#               'num_recreation_busi': 1061,
#               'num_scientific_busi': 8504,
#               'num_mining_busi': 130,
#               'num_finance_busi': 6007,
#               'num_agri_busi': 749},
#              '310': {'sentiment_score': 0.5939180802647911,
#               'tweet_counts': 4834,
#               'sent_sum': 2871,
#               'equivalised_total_household_income_census_median_weekly': 793,
#               'rent_mortgage_payments_census_average_monthly_household_payment': 1706,
#               'unemployed_rate': 20.98310276,
#               'avg_duration_job_search_wks': 67.25279631,
#               'persons_total': 342529,
#               'centroid': [152.55, -27.61],
#               'num_recreation_busi': 224,
#               'num_scientific_busi': 1737,
#               'num_mining_busi': 53,
#               'num_finance_busi': 981,
#               'num_agri_busi': 1931},
#              '311': {'sentiment_score': -0.08498023715415019,
#               'tweet_counts': 506,
#               'sent_sum': -43,
#               'equivalised_total_household_income_census_median_weekly': 799,
#               'rent_mortgage_payments_census_average_monthly_household_payment': 1784,
#               'unemployed_rate': 12.72767689,
#               'avg_duration_job_search_wks': 19.15853152,
#               'persons_total': 335102,
#               'centroid': [152.96, -28],
#               'num_recreation_busi': 272,
#               'num_scientific_busi': 2035,
#               'num_mining_busi': 29,
#               'num_finance_busi': 1446,
#               'num_agri_busi': 752},
#              '312': {'sentiment_score': 0.6216216216216216,
#               'tweet_counts': 111,
#               'sent_sum': 69,
#               'equivalised_total_household_income_census_median_weekly': 913,
#               'rent_mortgage_payments_census_average_monthly_household_payment': 1952,
#               'unemployed_rate': 5.83329942,
#               'avg_duration_job_search_wks': 17.81855404,
#               'persons_total': 172587,
#               'centroid': [147.92, -21.75],
#               'num_recreation_busi': 110,
#               'num_scientific_busi': 1032,
#               'num_mining_busi': 147,
#               'num_finance_busi': 915,
#               'num_agri_busi': 3331},
#              '313': {'sentiment_score': 3.166921022510492,
#               'tweet_counts': 5242,
#               'sent_sum': 16601,
#               'equivalised_total_household_income_census_median_weekly': 725,
#               'rent_mortgage_payments_census_average_monthly_household_payment': 1756,
#               'unemployed_rate': 5.30859047,
#               'avg_duration_job_search_wks': 36.91089149,
#               'persons_total': 247442,
#               'centroid': [152.53, -26.85],
#               'num_recreation_busi': 152,
#               'num_scientific_busi': 1370,
#               'num_mining_busi': 30,
#               'num_finance_busi': 890,
#               'num_agri_busi': 920},
#              '314': {'sentiment_score': 0.44680851063829785,
#               'tweet_counts': 47,
#               'sent_sum': 21,
#               'equivalised_total_household_income_census_median_weekly': 983,
#               'rent_mortgage_payments_census_average_monthly_household_payment': 1981,
#               'unemployed_rate': 10.09302401,
#               'avg_duration_job_search_wks': 13.14674875,
#               'persons_total': 207879,
#               'centroid': [152.86, -27.27],
#               'num_recreation_busi': 205,
#               'num_scientific_busi': 1967,
#               'num_mining_busi': 31,
#               'num_finance_busi': 1028,
#               'num_agri_busi': 236},
#              '316': {'sentiment_score': 0.6273168729909034,
#               'tweet_counts': 14621,
#               'sent_sum': 9172,
#               'equivalised_total_household_income_census_median_weekly': 779,
#               'rent_mortgage_payments_census_average_monthly_household_payment': 1879,
#               'unemployed_rate': 9.21046111,
#               'avg_duration_job_search_wks': 17.02008651,
#               'persons_total': 365839,
#               'centroid': [152.91, -26.59],
#               'num_recreation_busi': 508,
#               'num_scientific_busi': 4686,
#               'num_mining_busi': 77,
#               'num_finance_busi': 3664,
#               'num_agri_busi': 1466},
#              '317': {'sentiment_score': 0.51,
#               'tweet_counts': 5200,
#               'sent_sum': 2652,
#               'equivalised_total_household_income_census_median_weekly': 810,
#               'rent_mortgage_payments_census_average_monthly_household_payment': 1674,
#               'unemployed_rate': 9.23115056,
#               'avg_duration_job_search_wks': 27.46049134,
#               'persons_total': 154843,
#               'centroid': [152.08, -27.62],
#               'num_recreation_busi': 157,
#               'num_scientific_busi': 1175,
#               'num_mining_busi': 50,
#               'num_finance_busi': 1116,
#               'num_agri_busi': 1418},
#              '318': {'sentiment_score': 0.29411764705882354,
#               'tweet_counts': 34,
#               'sent_sum': 10,
#               'equivalised_total_household_income_census_median_weekly': 851,
#               'rent_mortgage_payments_census_average_monthly_household_payment': 1761,
#               'unemployed_rate': 7.56565505,
#               'avg_duration_job_search_wks': 22.86925393,
#               'persons_total': 235683,
#               'centroid': [145.93, -20.04],
#               'num_recreation_busi': 152,
#               'num_scientific_busi': 1358,
#               'num_mining_busi': 86,
#               'num_finance_busi': 953,
#               'num_agri_busi': 2709},
#              '319': {'sentiment_score': -0.5,
#               'tweet_counts': 84,
#               'sent_sum': -42,
#               'equivalised_total_household_income_census_median_weekly': 600,
#               'rent_mortgage_payments_census_average_monthly_household_payment': 1419,
#               'unemployed_rate': 13.63330398,
#               'avg_duration_job_search_wks': 106.5578285,
#               'persons_total': 294368,
#               'centroid': [151.74, -25.64],
#               'num_recreation_busi': 176,
#               'num_scientific_busi': 1215,
#               'num_mining_busi': 78,
#               'num_finance_busi': 1237,
#               'num_agri_busi': 5716},
#              '401': {'sentiment_score': 0.4039159264356312,
#               'tweet_counts': 95916,
#               'sent_sum': 38742,
#               'equivalised_total_household_income_census_median_weekly': 948,
#               'rent_mortgage_payments_census_average_monthly_household_payment': 1969,
#               'unemployed_rate': 10.13629689,
#               'avg_duration_job_search_wks': 33.80606553,
#               'persons_total': 299889,
#               'centroid': [138.84, -34.97],
#               'num_recreation_busi': 499,
#               'num_scientific_busi': 6723,
#               'num_mining_busi': 231,
#               'num_finance_busi': 9189,
#               'num_agri_busi': 1777},
#              '402': {'sentiment_score': 0.5199491740787802,
#               'tweet_counts': 3935,
#               'sent_sum': 2046,
#               'equivalised_total_household_income_census_median_weekly': 727,
#               'rent_mortgage_payments_census_average_monthly_household_payment': 1507,
#               'unemployed_rate': 20.69858503,
#               'avg_duration_job_search_wks': 54.91416044,
#               'persons_total': 434292,
#               'centroid': [138.66, -34.69],
#               'num_recreation_busi': 227,
#               'num_scientific_busi': 1636,
#               'num_mining_busi': 37,
#               'num_finance_busi': 1105,
#               'num_agri_busi': 1129},
#              '403': {'sentiment_score': 0.24050632911392406,
#               'tweet_counts': 1185,
#               'sent_sum': 285,
#               'equivalised_total_household_income_census_median_weekly': 816,
#               'rent_mortgage_payments_census_average_monthly_household_payment': 1668,
#               'unemployed_rate': 12.1255583,
#               'avg_duration_job_search_wks': 65.70285136,
#               'persons_total': 365060,
#               'centroid': [138.57, -35.14],
#               'num_recreation_busi': 317,
#               'num_scientific_busi': 2680,
#               'num_mining_busi': 40,
#               'num_finance_busi': 1712,
#               'num_agri_busi': 794},
#              '404': {'sentiment_score': -0.03859060402684564,
#               'tweet_counts': 1192,
#               'sent_sum': -46,
#               'equivalised_total_household_income_census_median_weekly': 774,
#               'rent_mortgage_payments_census_average_monthly_household_payment': 1748,
#               'unemployed_rate': 7.1045157,
#               'avg_duration_job_search_wks': 27.37277243,
#               'persons_total': 234926,
#               'centroid': [138.53, -34.88],
#               'num_recreation_busi': 227,
#               'num_scientific_busi': 1781,
#               'num_mining_busi': 33,
#               'num_finance_busi': 1238,
#               'num_agri_busi': 234},
#              '405': {'sentiment_score': 0.21666666666666667,
#               'tweet_counts': 120,
#               'sent_sum': 26,
#               'equivalised_total_household_income_census_median_weekly': 668,
#               'rent_mortgage_payments_census_average_monthly_household_payment': 1283,
#               'unemployed_rate': 4.98548941,
#               'avg_duration_job_search_wks': 18.55458068,
#               'persons_total': 113578,
#               'centroid': [138.45, -33.66],
#               'num_recreation_busi': 68,
#               'num_scientific_busi': 477,
#               'num_mining_busi': 22,
#               'num_finance_busi': 505,
#               'num_agri_busi': 4147},
#              '406': {'sentiment_score': 4.0,
#               'tweet_counts': 1,
#               'sent_sum': 4,
#               'equivalised_total_household_income_census_median_weekly': 728,
#               'rent_mortgage_payments_census_average_monthly_household_payment': 1350,
#               'unemployed_rate': 2.45575121,
#               'avg_duration_job_search_wks': 69.2928823,
#               'persons_total': 85132,
#               'centroid': [135.38, -29.48],
#               'num_recreation_busi': 32,
#               'num_scientific_busi': 240,
#               'num_mining_busi': 64,
#               'num_finance_busi': 455,
#               'num_agri_busi': 2048},
#              '407': {'sentiment_score': 1.0,
#               'tweet_counts': 12,
#               'sent_sum': 12,
#               'equivalised_total_household_income_census_median_weekly': 655,
#               'rent_mortgage_payments_census_average_monthly_household_payment': 1270,
#               'unemployed_rate': 6.18188624,
#               'avg_duration_job_search_wks': 55.38030343,
#               'persons_total': 190794,
#               'centroid': [140.11, -35.69],
#               'num_recreation_busi': 153,
#               'num_scientific_busi': 910,
#               'num_mining_busi': 50,
#               'num_finance_busi': 911,
#               'num_agri_busi': 6930},
#              '501': {'sentiment_score': 1.3051696652243225,
#               'tweet_counts': 8782,
#               'sent_sum': 11462,
#               'equivalised_total_household_income_census_median_weekly': 819,
#               'rent_mortgage_payments_census_average_monthly_household_payment': 1834,
#               'unemployed_rate': 2.88206674,
#               'avg_duration_job_search_wks': 12.44415312,
#               'persons_total': 181091,
#               'centroid': [116.01, -33.95],
#               'num_recreation_busi': 166,
#               'num_scientific_busi': 1208,
#               'num_mining_busi': 50,
#               'num_finance_busi': 1208,
#               'num_agri_busi': 3020},
#              '502': {'sentiment_score': -0.04871060171919771,
#               'tweet_counts': 698,
#               'sent_sum': -34,
#               'equivalised_total_household_income_census_median_weekly': 746,
#               'rent_mortgage_payments_census_average_monthly_household_payment': 1921,
#               'unemployed_rate': 4.23322062,
#               'avg_duration_job_search_wks': 24.4839346,
#               'persons_total': 100591,
#               'centroid': [115.85, -32.63],
#               'num_recreation_busi': 76,
#               'num_scientific_busi': 494,
#               'num_mining_busi': 31,
#               'num_finance_busi': 490,
#               'num_agri_busi': 284},
#              '503': {'sentiment_score': 0.542185428321961,
#               'tweet_counts': 92769,
#               'sent_sum': 50298,
#               'equivalised_total_household_income_census_median_weekly': 1368,
#               'rent_mortgage_payments_census_average_monthly_household_payment': 2663,
#               'unemployed_rate': 4.262752,
#               'avg_duration_job_search_wks': 19.6159338,
#               'persons_total': 179980,
#               'centroid': [115.81, -31.96],
#               'num_recreation_busi': 381,
#               'num_scientific_busi': 7352,
#               'num_mining_busi': 1477,
#               'num_finance_busi': 5994,
#               'num_agri_busi': 701},
#              '504': {'sentiment_score': 0.4277527195542584,
#               'tweet_counts': 18845,
#               'sent_sum': 8061,
#               'equivalised_total_household_income_census_median_weekly': 951,
#               'rent_mortgage_payments_census_average_monthly_household_payment': 2050,
#               'unemployed_rate': 9.52476229,
#               'avg_duration_job_search_wks': 38.56169655,
#               'persons_total': 262350,
#               'centroid': [116.13, -31.81],
#               'num_recreation_busi': 259,
#               'num_scientific_busi': 2314,
#               'num_mining_busi': 133,
#               'num_finance_busi': 1427,
#               'num_agri_busi': 524},
#              '505': {'sentiment_score': 0.8409669211195929,
#               'tweet_counts': 786,
#               'sent_sum': 661,
#               'equivalised_total_household_income_census_median_weekly': 1023,
#               'rent_mortgage_payments_census_average_monthly_household_payment': 2165,
#               'unemployed_rate': 24.43121222,
#               'avg_duration_job_search_wks': 39.29492911,
#               'persons_total': 561102,
#               'centroid': [115.77, -31.66],
#               'num_recreation_busi': 521,
#               'num_scientific_busi': 6079,
#               'num_mining_busi': 263,
#               'num_finance_busi': 4250,
#               'num_agri_busi': 685},
#              '506': {'sentiment_score': 0.6,
#               'tweet_counts': 5,
#               'sent_sum': 3,
#               'equivalised_total_household_income_census_median_weekly': 935,
#               'rent_mortgage_payments_census_average_monthly_household_payment': 2042,
#               'unemployed_rate': 17.98342849,
#               'avg_duration_job_search_wks': 36.80513193,
#               'persons_total': 511002,
#               'centroid': [116.06, -32.21],
#               'num_recreation_busi': 464,
#               'num_scientific_busi': 4678,
#               'num_mining_busi': 312,
#               'num_finance_busi': 3194,
#               'num_agri_busi': 813},
#              '509': {'sentiment_score': 0.819047619047619,
#               'tweet_counts': 105,
#               'sent_sum': 86,
#               'equivalised_total_household_income_census_median_weekly': 767,
#               'rent_mortgage_payments_census_average_monthly_household_payment': 1568,
#               'unemployed_rate': 2.78154759,
#               'avg_duration_job_search_wks': 27.64521124,
#               'persons_total': 137666,
#               'centroid': [117.92, -32.07],
#               'num_recreation_busi': 80,
#               'num_scientific_busi': 744,
#               'num_mining_busi': 67,
#               'num_finance_busi': 778,
#               'num_agri_busi': 6893},
#              '601': {'sentiment_score': 0.3499453985902909,
#               'tweet_counts': 20146,
#               'sent_sum': 7050,
#               'equivalised_total_household_income_census_median_weekly': 798,
#               'rent_mortgage_payments_census_average_monthly_household_payment': 1531,
#               'unemployed_rate': 8.58775379,
#               'avg_duration_job_search_wks': 63.50588538,
#               'persons_total': 229088,
#               'centroid': [147.44, -42.83],
#               'num_recreation_busi': 261,
#               'num_scientific_busi': 2008,
#               'num_mining_busi': 37,
#               'num_finance_busi': 1236,
#               'num_agri_busi': 706},
#              '602': {'sentiment_score': 0.5068807339449541,
#               'tweet_counts': 1308,
#               'sent_sum': 663,
#               'equivalised_total_household_income_census_median_weekly': 666,
#               'rent_mortgage_payments_census_average_monthly_household_payment': 1357,
#               'unemployed_rate': 3.80502011,
#               'avg_duration_job_search_wks': 124.4736611,
#               'persons_total': 143752,
#               'centroid': [147.39, -41.5],
#               'num_recreation_busi': 128,
#               'num_scientific_busi': 926,
#               'num_mining_busi': 27,
#               'num_finance_busi': 774,
#               'num_agri_busi': 2010},
#              '603': {'sentiment_score': 0.35856573705179284,
#               'tweet_counts': 251,
#               'sent_sum': 90,
#               'equivalised_total_household_income_census_median_weekly': 625,
#               'rent_mortgage_payments_census_average_monthly_household_payment': 1277,
#               'unemployed_rate': 0.85496087,
#               'avg_duration_job_search_wks': 57.13830856,
#               'persons_total': 38053,
#               'centroid': [146.82, -42.61],
#               'num_recreation_busi': 41,
#               'num_scientific_busi': 248,
#               'num_mining_busi': 11,
#               'num_finance_busi': 134,
#               'num_agri_busi': 958},
#              '604': {'sentiment_score': 0.4824561403508772,
#               'tweet_counts': 114,
#               'sent_sum': 55,
#               'equivalised_total_household_income_census_median_weekly': 644,
#               'rent_mortgage_payments_census_average_monthly_household_payment': 1271,
#               'unemployed_rate': 3.02526616,
#               'avg_duration_job_search_wks': 92.97848739,
#               'persons_total': 111259,
#               'centroid': [145.56, -41.73],
#               'num_recreation_busi': 71,
#               'num_scientific_busi': 506,
#               'num_mining_busi': 43,
#               'num_finance_busi': 511,
#               'num_agri_busi': 1870},
#              '701': {'sentiment_score': 0.10640509289333507,
#               'tweet_counts': 7697,
#               'sent_sum': 819,
#               'equivalised_total_household_income_census_median_weekly': 1316,
#               'rent_mortgage_payments_census_average_monthly_household_payment': 2383,
#               'unemployed_rate': 5.4048757,
#               'avg_duration_job_search_wks': 16.70776338,
#               'persons_total': 148884,
#               'centroid': [131.11, -12.53],
#               'num_recreation_busi': 148,
#               'num_scientific_busi': 1122,
#               'num_mining_busi': 54,
#               'num_finance_busi': 706,
#               'num_agri_busi': 437},
#              '702': {'sentiment_score': 0.8620689655172413,
#               'tweet_counts': 29,
#               'sent_sum': 25,
#               'equivalised_total_household_income_census_median_weekly': 954,
#               'rent_mortgage_payments_census_average_monthly_household_payment': 1945,
#               'unemployed_rate': 3.11781354,
#               'avg_duration_job_search_wks': 36.04104361,
#               'persons_total': 98607,
#               'centroid': [133.37, -19.49],
#               'num_recreation_busi': 53,
#               'num_scientific_busi': 269,
#               'num_mining_busi': 19,
#               'num_finance_busi': 180,
#               'num_agri_busi': 449},
#              '801': {'sentiment_score': 0.2847026236019651,
#               'tweet_counts': 38268,
#               'sent_sum': 10895,
#               'equivalised_total_household_income_census_median_weekly': 1297,
#               'rent_mortgage_payments_census_average_monthly_household_payment': 2178,
#               'persons_total': 411667,
#               'centroid': [149, -35.49],
#               'num_recreation_busi': 429,
#               'num_scientific_busi': 5549,
#               'num_mining_busi': 27,
#               'num_finance_busi': 2282,
#               'num_agri_busi': 345}})

# %%
# sent_scores

# %%
data_df=pd.DataFrame.from_dict(data_dict, orient='index')

# %%
data_df.corr()
# Out:
#                                                     sentiment_score  \
# sentiment_score                                            1.000000
# tweet_counts                                              -0.040376
# sent_sum                                                   0.025819
# equivalised_total_household_income_census_media...        -0.058381
# rent_mortgage_payments_census_average_monthly_h...        -0.087398
# unemployed_rate                                           -0.072462
# avg_duration_job_search_wks                                0.060013
# persons_total                                             -0.042855
# num_recreation_busi                                       -0.062942
# num_scientific_busi                                       -0.022107
# num_mining_busi                                            0.003448
# num_finance_busi                                          -0.010999
# num_agri_busi                                              0.055682
# total_division_a_offences                                  0.343562
# total_division_b_offences                                  0.382714
# total_division_c_offences                                  0.332001
# total_division_d_offences                                  0.146144
# total_division_e_offences                                  0.250979
# total_division_f_offences                                  0.188998
# sum_crimes                                                 0.352827
#
#                                                     tweet_counts  sent_sum  \
# sentiment_score                                        -0.040376  0.025819
# tweet_counts                                            1.000000  0.989362
# sent_sum                                                0.989362  1.000000
# equivalised_total_household_income_census_media...      0.303421  0.291482
# rent_mortgage_payments_census_average_monthly_h...      0.221303  0.220610
# unemployed_rate                                         0.288580  0.294079
# avg_duration_job_search_wks                            -0.143239 -0.141949
# persons_total                                           0.258604  0.258684
# num_recreation_busi                                     0.662931  0.664456
# num_scientific_busi                                     0.630515  0.631479
# num_mining_busi                                         0.413188  0.425523
# num_finance_busi                                        0.670560  0.667835
# num_agri_busi                                          -0.113120 -0.113343
# total_division_a_offences                               0.022374  0.024104
# total_division_b_offences                               0.219800  0.222653
# total_division_c_offences                               0.196972  0.199405
# total_division_d_offences                               0.184892  0.185130
# total_division_e_offences                              -0.053644 -0.054669
# total_division_f_offences                              -0.050953 -0.047092
# sum_crimes                                              0.157614  0.159677
#
#                                                     equivalised_total_household_income_census_median_weekly  \
# sentiment_score                                                                             -0.058381
# tweet_counts                                                                                 0.303421
# sent_sum                                                                                     0.291482
# equivalised_total_household_income_census_media...                                           1.000000
# rent_mortgage_payments_census_average_monthly_h...                                           0.904217
# unemployed_rate                                                                              0.195451
# avg_duration_job_search_wks                                                                 -0.463919
# persons_total                                                                                0.226448
# num_recreation_busi                                                                          0.536205
# num_scientific_busi                                                                          0.656746
# num_mining_busi                                                                              0.376348
# num_finance_busi                                                                             0.593276
# num_agri_busi                                                                               -0.502420
# total_division_a_offences                                                                    0.193747
# total_division_b_offences                                                                    0.440954
# total_division_c_offences                                                                    0.317484
# total_division_d_offences                                                                    0.228467
# total_division_e_offences                                                                    0.053529
# total_division_f_offences                                                                    0.396397
# sum_crimes                                                                                   0.346146
#
#                                                     rent_mortgage_payments_census_average_monthly_household_payment  \
# sentiment_score                                                                             -0.087398
# tweet_counts                                                                                 0.221303
# sent_sum                                                                                     0.220610
# equivalised_total_household_income_census_media...                                           0.904217
# rent_mortgage_payments_census_average_monthly_h...                                           1.000000
# unemployed_rate                                                                              0.311829
# avg_duration_job_search_wks                                                                 -0.498076
# persons_total                                                                                0.351770
# num_recreation_busi                                                                          0.546410
# num_scientific_busi                                                                          0.646868
# num_mining_busi                                                                              0.287662
# num_finance_busi                                                                             0.569307
# num_agri_busi                                                                               -0.610097
# total_division_a_offences                                                                    0.330655
# total_division_b_offences                                                                    0.540447
# total_division_c_offences                                                                    0.428065
# total_division_d_offences                                                                    0.330079
# total_division_e_offences                                                                    0.185802
# total_division_f_offences                                                                    0.522932
# sum_crimes                                                                                   0.459986
#
#                                                     unemployed_rate  \
# sentiment_score                                           -0.072462
# tweet_counts                                               0.288580
# sent_sum                                                   0.294079
# equivalised_total_household_income_census_media...         0.195451
# rent_mortgage_payments_census_average_monthly_h...         0.311829
# unemployed_rate                                            1.000000
# avg_duration_job_search_wks                               -0.111898
# persons_total                                              0.910267
# num_recreation_busi                                        0.610682
# num_scientific_busi                                        0.565576
# num_mining_busi                                            0.057184
# num_finance_busi                                           0.500730
# num_agri_busi                                             -0.352382
# total_division_a_offences                                  0.574023
# total_division_b_offences                                  0.567434
# total_division_c_offences                                  0.661857
# total_division_d_offences                                  0.560054
# total_division_e_offences                                  0.403944
# total_division_f_offences                                  0.604531
# sum_crimes                                                 0.572063
#
#                                                     avg_duration_job_search_wks  \
# sentiment_score                                                        0.060013
# tweet_counts                                                          -0.143239
# sent_sum                                                              -0.141949
# equivalised_total_household_income_census_media...                    -0.463919
# rent_mortgage_payments_census_average_monthly_h...                    -0.498076
# unemployed_rate                                                       -0.111898
# avg_duration_job_search_wks                                            1.000000
# persons_total                                                         -0.178032
# num_recreation_busi                                                   -0.294929
# num_scientific_busi                                                   -0.323298
# num_mining_busi                                                       -0.103570
# num_finance_busi                                                      -0.293062
# num_agri_busi                                                          0.250221
# total_division_a_offences                                             -0.124142
# total_division_b_offences                                             -0.133021
# total_division_c_offences                                             -0.177694
# total_division_d_offences                                             -0.223935
# total_division_e_offences                                             -0.161674
# total_division_f_offences                                             -0.019730
# sum_crimes                                                            -0.149221
#
#                                                     persons_total  \
# sentiment_score                                         -0.042855
# tweet_counts                                             0.258604
# sent_sum                                                 0.258684
# equivalised_total_household_income_census_media...       0.226448
# rent_mortgage_payments_census_average_monthly_h...       0.351770
# unemployed_rate                                          0.910267
# avg_duration_job_search_wks                             -0.178032
# persons_total                                            1.000000
# num_recreation_busi                                      0.645307
# num_scientific_busi                                      0.604895
# num_mining_busi                                          0.034336
# num_finance_busi                                         0.523038
# num_agri_busi                                           -0.369973
# total_division_a_offences                                0.667731
# total_division_b_offences                                0.664901
# total_division_c_offences                                0.719857
# total_division_d_offences                                0.592793
# total_division_e_offences                                0.485678
# total_division_f_offences                                0.695104
# sum_crimes                                               0.663436
#
#                                                     num_recreation_busi  \
# sentiment_score                                               -0.062942
# tweet_counts                                                   0.662931
# sent_sum                                                       0.664456
# equivalised_total_household_income_census_media...             0.536205
# rent_mortgage_payments_census_average_monthly_h...             0.546410
# unemployed_rate                                                0.610682
# avg_duration_job_search_wks                                   -0.294929
# persons_total                                                  0.645307
# num_recreation_busi                                            1.000000
# num_scientific_busi                                            0.953200
# num_mining_busi                                                0.241742
# num_finance_busi                                               0.912836
# num_agri_busi                                                 -0.326404
# total_division_a_offences                                      0.259135
# total_division_b_offences                                      0.445150
# total_division_c_offences                                      0.429596
# total_division_d_offences                                      0.375984
# total_division_e_offences                                      0.127455
# total_division_f_offences                                      0.271864
# sum_crimes                                                     0.385062
#
#                                                     num_scientific_busi  \
# sentiment_score                                               -0.022107
# tweet_counts                                                   0.630515
# sent_sum                                                       0.631479
# equivalised_total_household_income_census_media...             0.656746
# rent_mortgage_payments_census_average_monthly_h...             0.646868
# unemployed_rate                                                0.565576
# avg_duration_job_search_wks                                   -0.323298
# persons_total                                                  0.604895
# num_recreation_busi                                            0.953200
# num_scientific_busi                                            1.000000
# num_mining_busi                                                0.353589
# num_finance_busi                                               0.969027
# num_agri_busi                                                 -0.368311
# total_division_a_offences                                      0.234784
# total_division_b_offences                                      0.433107
# total_division_c_offences                                      0.408195
# total_division_d_offences                                      0.334566
# total_division_e_offences                                      0.085870
# total_division_f_offences                                      0.295902
# sum_crimes                                                     0.364259
#
#                                                     num_mining_busi  \
# sentiment_score                                            0.003448
# tweet_counts                                               0.413188
# sent_sum                                                   0.425523
# equivalised_total_household_income_census_media...         0.376348
# rent_mortgage_payments_census_average_monthly_h...         0.287662
# unemployed_rate                                            0.057184
# avg_duration_job_search_wks                               -0.103570
# persons_total                                              0.034336
# num_recreation_busi                                        0.241742
# num_scientific_busi                                        0.353589
# num_mining_busi                                            1.000000
# num_finance_busi                                           0.413695
# num_agri_busi                                             -0.062730
# total_division_a_offences                                  0.011321
# total_division_b_offences                                  0.160564
# total_division_c_offences                                  0.181238
# total_division_d_offences                                  0.189951
# total_division_e_offences                                 -0.059054
# total_division_f_offences                                 -0.087089
# sum_crimes                                                 0.117713
#
#                                                     num_finance_busi  \
# sentiment_score                                            -0.010999
# tweet_counts                                                0.670560
# sent_sum                                                    0.667835
# equivalised_total_household_income_census_media...          0.593276
# rent_mortgage_payments_census_average_monthly_h...          0.569307
# unemployed_rate                                             0.500730
# avg_duration_job_search_wks                                -0.293062
# persons_total                                               0.523038
# num_recreation_busi                                         0.912836
# num_scientific_busi                                         0.969027
# num_mining_busi                                             0.413695
# num_finance_busi                                            1.000000
# num_agri_busi                                              -0.288657
# total_division_a_offences                                   0.172074
# total_division_b_offences                                   0.385998
# total_division_c_offences                                   0.355599
# total_division_d_offences                                   0.293421
# total_division_e_offences                                   0.031164
# total_division_f_offences                                   0.229360
# sum_crimes                                                  0.312197
#
#                                                     num_agri_busi  \
# sentiment_score                                          0.055682
# tweet_counts                                            -0.113120
# sent_sum                                                -0.113343
# equivalised_total_household_income_census_media...      -0.502420
# rent_mortgage_payments_census_average_monthly_h...      -0.610097
# unemployed_rate                                         -0.352382
# avg_duration_job_search_wks                              0.250221
# persons_total                                           -0.369973
# num_recreation_busi                                     -0.326404
# num_scientific_busi                                     -0.368311
# num_mining_busi                                         -0.062730
# num_finance_busi                                        -0.288657
# num_agri_busi                                            1.000000
# total_division_a_offences                               -0.572655
# total_division_b_offences                               -0.714916
# total_division_c_offences                               -0.583661
# total_division_d_offences                               -0.518464
# total_division_e_offences                               -0.513178
# total_division_f_offences                               -0.702778
# sum_crimes                                              -0.671100
#
#                                                     total_division_a_offences  \
# sentiment_score                                                      0.343562
# tweet_counts                                                         0.022374
# sent_sum                                                             0.024104
# equivalised_total_household_income_census_media...                   0.193747
# rent_mortgage_payments_census_average_monthly_h...                   0.330655
# unemployed_rate                                                      0.574023
# avg_duration_job_search_wks                                         -0.124142
# persons_total                                                        0.667731
# num_recreation_busi                                                  0.259135
# num_scientific_busi                                                  0.234784
# num_mining_busi                                                      0.011321
# num_finance_busi                                                     0.172074
# num_agri_busi                                                       -0.572655
# total_division_a_offences                                            1.000000
# total_division_b_offences                                            0.925021
# total_division_c_offences                                            0.953169
# total_division_d_offences                                            0.880030
# total_division_e_offences                                            0.955491
# total_division_f_offences                                            0.778956
# sum_crimes                                                           0.971638
#
#                                                     total_division_b_offences  \
# sentiment_score                                                      0.382714
# tweet_counts                                                         0.219800
# sent_sum                                                             0.222653
# equivalised_total_household_income_census_media...                   0.440954
# rent_mortgage_payments_census_average_monthly_h...                   0.540447
# unemployed_rate                                                      0.567434
# avg_duration_job_search_wks                                         -0.133021
# persons_total                                                        0.664901
# num_recreation_busi                                                  0.445150
# num_scientific_busi                                                  0.433107
# num_mining_busi                                                      0.160564
# num_finance_busi                                                     0.385998
# num_agri_busi                                                       -0.714916
# total_division_a_offences                                            0.925021
# total_division_b_offences                                            1.000000
# total_division_c_offences                                            0.901527
# total_division_d_offences                                            0.813800
# total_division_e_offences                                            0.847291
# total_division_f_offences                                            0.807745
# sum_crimes                                                           0.985134
#
#                                                     total_division_c_offences  \
# sentiment_score                                                      0.332001
# tweet_counts                                                         0.196972
# sent_sum                                                             0.199405
# equivalised_total_household_income_census_media...                   0.317484
# rent_mortgage_payments_census_average_monthly_h...                   0.428065
# unemployed_rate                                                      0.661857
# avg_duration_job_search_wks                                         -0.177694
# persons_total                                                        0.719857
# num_recreation_busi                                                  0.429596
# num_scientific_busi                                                  0.408195
# num_mining_busi                                                      0.181238
# num_finance_busi                                                     0.355599
# num_agri_busi                                                       -0.583661
# total_division_a_offences                                            0.953169
# total_division_b_offences                                            0.901527
# total_division_c_offences                                            1.000000
# total_division_d_offences                                            0.935466
# total_division_e_offences                                            0.887069
# total_division_f_offences                                            0.771647
# sum_crimes                                                           0.947654
#
#                                                     total_division_d_offences  \
# sentiment_score                                                      0.146144
# tweet_counts                                                         0.184892
# sent_sum                                                             0.185130
# equivalised_total_household_income_census_media...                   0.228467
# rent_mortgage_payments_census_average_monthly_h...                   0.330079
# unemployed_rate                                                      0.560054
# avg_duration_job_search_wks                                         -0.223935
# persons_total                                                        0.592793
# num_recreation_busi                                                  0.375984
# num_scientific_busi                                                  0.334566
# num_mining_busi                                                      0.189951
# num_finance_busi                                                     0.293421
# num_agri_busi                                                       -0.518464
# total_division_a_offences                                            0.880030
# total_division_b_offences                                            0.813800
# total_division_c_offences                                            0.935466
# total_division_d_offences                                            1.000000
# total_division_e_offences                                            0.887260
# total_division_f_offences                                            0.745064
# sum_crimes                                                           0.883058
#
#                                                     total_division_e_offences  \
# sentiment_score                                                      0.250979
# tweet_counts                                                        -0.053644
# sent_sum                                                            -0.054669
# equivalised_total_household_income_census_media...                   0.053529
# rent_mortgage_payments_census_average_monthly_h...                   0.185802
# unemployed_rate                                                      0.403944
# avg_duration_job_search_wks                                         -0.161674
# persons_total                                                        0.485678
# num_recreation_busi                                                  0.127455
# num_scientific_busi                                                  0.085870
# num_mining_busi                                                     -0.059054
# num_finance_busi                                                     0.031164
# num_agri_busi                                                       -0.513178
# total_division_a_offences                                            0.955491
# total_division_b_offences                                            0.847291
# total_division_c_offences                                            0.887069
# total_division_d_offences                                            0.887260
# total_division_e_offences                                            1.000000
# total_division_f_offences                                            0.678599
# sum_crimes                                                           0.919075
#
#                                                     total_division_f_offences  \
# sentiment_score                                                      0.188998
# tweet_counts                                                        -0.050953
# sent_sum                                                            -0.047092
# equivalised_total_household_income_census_media...                   0.396397
# rent_mortgage_payments_census_average_monthly_h...                   0.522932
# unemployed_rate                                                      0.604531
# avg_duration_job_search_wks                                         -0.019730
# persons_total                                                        0.695104
# num_recreation_busi                                                  0.271864
# num_scientific_busi                                                  0.295902
# num_mining_busi                                                     -0.087089
# num_finance_busi                                                     0.229360
# num_agri_busi                                                       -0.702778
# total_division_a_offences                                            0.778956
# total_division_b_offences                                            0.807745
# total_division_c_offences                                            0.771647
# total_division_d_offences                                            0.745064
# total_division_e_offences                                            0.678599
# total_division_f_offences                                            1.000000
# sum_crimes                                                           0.809255
#
#                                                     sum_crimes
# sentiment_score                                       0.352827
# tweet_counts                                          0.157614
# sent_sum                                              0.159677
# equivalised_total_household_income_census_media...    0.346146
# rent_mortgage_payments_census_average_monthly_h...    0.459986
# unemployed_rate                                       0.572063
# avg_duration_job_search_wks                          -0.149221
# persons_total                                         0.663436
# num_recreation_busi                                   0.385062
# num_scientific_busi                                   0.364259
# num_mining_busi                                       0.117713
# num_finance_busi                                      0.312197
# num_agri_busi                                        -0.671100
# total_division_a_offences                             0.971638
# total_division_b_offences                             0.985134
# total_division_c_offences                             0.947654
# total_division_d_offences                             0.883058
# total_division_e_offences                             0.919075
# total_division_f_offences                             0.809255
# sum_crimes                                            1.000000

# %%
data_df
# Out:
#      sentiment_score  tweet_counts  sent_sum  \
# 101         0.284683         38643     11001
# 102         0.008370         18996       159
# 103         0.361404           855       309
# 104         0.246459           353        87
# 106         0.827586           812       672
# ..               ...           ...       ...
# 603         0.358566           251        90
# 604         0.482456           114        55
# 701         0.106405          7697       819
# 702         0.862069            29        25
# 801         0.284703         38268     10895
#
#      equivalised_total_household_income_census_median_weekly  \
# 101                                                795
# 102                                                774
# 103                                                742
# 104                                                648
# 106                                                786
# ..                                                 ...
# 603                                                625
# 604                                                644
# 701                                               1316
# 702                                                954
# 801                                               1297
#
#      rent_mortgage_payments_census_average_monthly_household_payment  \
# 101                                               1805
# 102                                               1890
# 103                                               1625
# 104                                               1568
# 106                                               1801
# ..                                                 ...
# 603                                               1277
# 604                                               1271
# 701                                               2383
# 702                                               1945
# 801                                               2178
#
#      unemployed_rate  avg_duration_job_search_wks  persons_total  \
# 101         5.762001                    21.297178         225666
# 102         9.205978                    13.639877         339236
# 103         5.622973                    28.566150         211224
# 104         2.280920                   138.112214         140070
# 106         7.075872                    25.035527         272452
# ..               ...                          ...            ...
# 603         0.854961                    57.138309          38053
# 604         3.025266                    92.978487         111259
# 701         5.404876                    16.707763         148884
# 702         3.117814                    36.041044          98607
# 801              NaN                          NaN         411667
#
#              centroid  num_recreation_busi  ...  num_mining_busi  \
# 101  [149.24, -35.56]                  264  ...               59
# 102  [151.29, -33.31]                  410  ...               52
# 103  [148.36, -33.22]                  192  ...              109
# 104  [152.77, -29.82]                  150  ...               33
# 106  [150.98, -32.35]                  250  ...               85
# ..                ...                  ...  ...              ...
# 603  [146.82, -42.61]                   41  ...               11
# 604  [145.56, -41.73]                   71  ...               43
# 701  [131.11, -12.53]                  148  ...               54
# 702  [133.37, -19.49]                   53  ...               19
# 801     [149, -35.49]                  429  ...               27
#
#      num_finance_busi  num_agri_busi  total_division_a_offences  \
# 101              1048           5059                        NaN
# 102              1916            512                        NaN
# 103              1006           6709                        NaN
# 104               749           1881                        NaN
# 106              2248           2914                        NaN
# ..                ...            ...                        ...
# 603               134            958                        NaN
# 604               511           1870                        NaN
# 701               706            437                        NaN
# 702               180            449                        NaN
# 801              2282            345                        NaN
#
#      total_division_b_offences  total_division_c_offences  \
# 101                        NaN                        NaN
# 102                        NaN                        NaN
# 103                        NaN                        NaN
# 104                        NaN                        NaN
# 106                        NaN                        NaN
# ..                         ...                        ...
# 603                        NaN                        NaN
# 604                        NaN                        NaN
# 701                        NaN                        NaN
# 702                        NaN                        NaN
# 801                        NaN                        NaN
#
#      total_division_d_offences  total_division_e_offences  \
# 101                        NaN                        NaN
# 102                        NaN                        NaN
# 103                        NaN                        NaN
# 104                        NaN                        NaN
# 106                        NaN                        NaN
# ..                         ...                        ...
# 603                        NaN                        NaN
# 604                        NaN                        NaN
# 701                        NaN                        NaN
# 702                        NaN                        NaN
# 801                        NaN                        NaN
#
#      total_division_f_offences  sum_crimes
# 101                        NaN         NaN
# 102                        NaN         NaN
# 103                        NaN         NaN
# 104                        NaN         NaN
# 106                        NaN         NaN
# ..                         ...         ...
# 603                        NaN         NaN
# 604                        NaN         NaN
# 701                        NaN         NaN
# 702                        NaN         NaN
# 801                        NaN         NaN
#
# [81 rows x 21 columns]

# %% [markdown]
# #### Process Output json

# %%
# Output processed geojson
def merge_data(data, sa4_geo):
    output={"type": "FeatureCollection", "features":[]}
    for row in sa4_geo['features']:
        key = row['properties']['SA4_CODE16']
        if key in data.keys():
            for feature in data[key].keys():
                row['properties'][feature]= data[key][feature]
        else:
            for feature in data[key].keys():
                row['properties'][feature]='No Record'
   
    with open('output.json', 'w') as outfile:
        json.dump(sa4_geo, outfile)

# %%
# merge_data(data_dict, sa4_geo_file)
# check = json.load(open('output.json'))

# %%
# for item in check['features']:
#     if item['properties']['SA4_CODE16'] == '117':
#         print(item)

# %%
len(data_dict)
# Out:
# 81

# %%
data_dict.keys()
# Out:
# dict_keys(['101', '102', '103', '104', '106', '107', '108', '110', '111', '112', '113', '114', '115', '116', '117', '118', '119', '120', '121', '122', '123', '124', '125', '126', '127', '128', '201', '202', '203', '204', '205', '206', '207', '208', '209', '210', '211', '212', '213', '214', '215', '216', '217', '301', '302', '303', '304', '305', '306', '307', '309', '310', '311', '312', '313', '314', '316', '317', '318', '319', '401', '402', '403', '404', '405', '406', '407', '501', '502', '503', '504', '505', '506', '509', '601', '602', '603', '604', '701', '702', '801'])
